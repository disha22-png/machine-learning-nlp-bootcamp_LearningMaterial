# %% [markdown]
# ## 5 number summary and box plot

# %%
## Max, Min, median, Q1, Q3, IQR

import numpy as np

lst_marks = [45,32,56,55,60,98,99,70,80]
minimum,Q1,median, Q3, maximum = np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median, Q3, maximum
# Out:
# (32.0, 55.0, 60.0, 80.0, 99.0)

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 25.0

# %%
lower_fence = Q1- 1.5*IQR
higher_fence = Q1 + 1.5*IQR

# %%
lower_fence
# Out:
# 17.5

# %%
higher_fence
# Out:
# 92.5

# %%
lst_marks = [45,32,56,55,60,98,99,70,80]

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [45,32,56,55,60,98,99,70,80,140,300,10,250,2,3]

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >
